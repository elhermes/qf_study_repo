# %%
import numpy as np

from quant_freedom_python import MACDandEMA

from quantfreedom.enums import *
from quantfreedom.helper_funcs import dl_ex_candles
from quantfreedom.simulate import run_df_backtest, or_backtest

np.set_printoptions(formatter={"float_kind": "{:0.2f}".format})

# %load_ext autoreload
# %autoreload 2

# %%
candles = dl_ex_candles(
      exchange="binance_us",
      symbol='BTCUSDT',
      timeframe='5m',
      candles_to_dl=100,  
)

# %%
macd_strat = MACDandEMA(
    long_short="long",
    ema_length = np.arange(50, 201, 20),
    fast_length = np.arange(10, 81, 10),
    macd_below = np.arange(0, 51, 25),
    signal_smoothing = np.arange(5, 16, 5),
    slow_length = np.arange(30, 210, 5),
)

# %%
backtest_settings = BacktestSettings()

exchange_settings = ExchangeSettings(
    asset_tick_step=3,
    leverage_mode=1,
    leverage_tick_step=2,
    limit_fee_pct=0.0005,
    market_fee_pct=0.0005,
    max_asset_size=100.0,
    max_leverage=100.0,
    min_asset_size=0.001,
    min_leverage=0.5,
    mmr_pct=0.004,
    position_mode=1,
    price_tick_step=1,
)

# %%
static_os = StaticOrderSettings(
    increase_position_type=IncreasePositionType.RiskPctAccountEntrySize,
    leverage_strategy_type=LeverageStrategyType.Dynamic,
    pg_min_max_sl_bcb="min",
    sl_strategy_type=StopLossStrategyType.SLBasedOnCandleBody,
    sl_to_be_bool=False,
    starting_bar=50,
    starting_equity=100.0,
    static_leverage=None,
    tp_fee_type="limit",
    tp_strategy_type=TakeProfitStrategyType.RiskReward,
    trail_sl_bool=True,
    z_or_e_type=None,
)

# %%
dos_arrays = DynamicOrderSettingsArrays(
    max_equity_risk_pct=np.array([5]),
    max_trades=np.array([0]),
    risk_account_pct_size=np.array([3]),
    risk_reward=np.array([5]),
    sl_based_on_add_pct=np.array([0.1, 0.25]),
    sl_based_on_lookback=np.array([20, 50]),
    sl_bcb_type=np.array([CandleBodyType.Low]),
    sl_to_be_cb_type=np.array([CandleBodyType.Nothing]),
    sl_to_be_when_pct=np.array([0]),
    trail_sl_bcb_type=np.array([CandleBodyType.Low]),
    trail_sl_by_pct=np.array([0.5, 1.0]),
    trail_sl_when_pct=np.array([1, 2]),
)

# %%
backtest_results = run_df_backtest(
    backtest_settings=backtest_settings,
    candles=candles,
    dos_arrays=dos_arrays,
    exchange_settings=exchange_settings,
    static_os=static_os,
    strategy=macd_strat,
)
# Out:
# Starting the backtest now ... and also here are some stats for your backtest.
#
# Total indicator settings to test: 18,144
# Total order settings to test: 16
# Total combinations of settings to test: 290,304
# Total candles: 100
# Total candles to test: 29,030,400
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\Bado\PycharmProjects\quant_freedom\quant_freedom_python.py:92, in MACDandEMA.long_set_entries_exits_array(self, candles, ind_set_index)
#      90 self.slow_length = self.indicator_settings_arrays.slow_length[ind_set_index]
# ---> 92 self.histogram, self.macd, self.signal = macd_tv(
#      93     source=closing_prices,
#      94     fast_length=self.fast_length,
#      95     slow_length=self.slow_length,
#      96     signal_smoothing=self.signal_smoothing,
#      97 )
#      99 self.ema = ema_tv(
#     100     source=closing_prices,
#     101     length=self.ema_length,
#     102 )
#
# File c:\Users\Bado\Desktop\qf\lib\site-packages\quantfreedom\indicators\tv_indicators.py:252, in macd_tv(source, fast_length, slow_length, signal_smoothing, oscillator_type, signal_ma_type)
#     251 macd = fast_ma - slow_ma
# --> 252 signal = signal_ma_type(source=macd, length=signal_smoothing)
#     253 histogram = macd - signal
#
# File c:\Users\Bado\Desktop\qf\lib\site-packages\quantfreedom\indicators\tv_indicators.py:95, in ema_tv(source, length)
#      94 ema = np.full_like(source, np.nan)
# ---> 95 ema[starting_index - 1] = source[starting_index - 1]
#      97 for index in range(starting_index, source.size):
#
# IndexError: index 103 is out of bounds for axis 0 with size 100
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 backtest_results = run_df_backtest(
#       2     backtest_settings=backtest_settings,
#       3     candles=candles,
#       4     dos_arrays=dos_arrays,
#       5     exchange_settings=exchange_settings,
#       6     static_os=static_os,
#       7     strategy=macd_strat,
#       8 )
#
# File c:\Users\Bado\Desktop\qf\lib\site-packages\quantfreedom\simulate.py:78, in run_df_backtest(backtest_settings, candles, dos_arrays, exchange_settings, static_os, strategy)
#      75 result_records_filled = 0
#      77 for ind_set_index in range(total_indicator_settings):
# ---> 78     strategy.set_entries_exits_array(
#      79         candles=candles,
#      80         ind_set_index=ind_set_index,
#      81     )
#      83     for dos_index in range(total_order_settings):
#      84         strategy.log_indicator_settings(ind_set_index=ind_set_index)
#
# File c:\Users\Bado\PycharmProjects\quant_freedom\quant_freedom_python.py:128, in MACDandEMA.long_set_entries_exits_array(self, candles, ind_set_index)
#     126 except Exception as e:
#     127     logger.error(f"Exception long_set_entries_exits_array -> {e}")
# --> 128     raise Exception(f"Exception long_set_entries_exits_array -> {e}")
#
# Exception: Exception long_set_entries_exits_array -> index 103 is out of bounds for axis 0 with size 100

# %%
backtest_results.sort_values(by=["qf_score"], ascending=False).head(10)
# Out:
#      ind_set_idx  dos_index  total_trades  wins  losses  gains_pct  win_rate  \
# 0            398          0           1.0     0       1     -2.087       0.0
# 268          909          8           1.0     0       1     -1.024       0.0
# 278          931         12           1.0     0       1     -1.024       0.0
# 277          931         10           1.0     0       1     -1.335       0.0
# 276          931          8           1.0     0       1     -1.024       0.0
# 275          931          6           1.0     0       1     -1.335       0.0
# 274          931          4           1.0     0       1     -1.024       0.0
# 273          931          2           1.0     0       1     -1.335       0.0
# 272          931          0           1.0     0       1     -1.024       0.0
# 271          909         14           1.0     0       1     -1.335       0.0
#
#      qf_score  fees_paid  ending_eq  total_pnl
# 0        -0.0      0.129     97.913     -2.087
# 268      -0.0      0.062     98.976     -1.024
# 278      -0.0      0.062     98.976     -1.024
# 277      -0.0      0.062     98.665     -1.335
# 276      -0.0      0.062     98.976     -1.024
# 275      -0.0      0.062     98.665     -1.335
# 274      -0.0      0.062     98.976     -1.024
# 273      -0.0      0.062     98.665     -1.335
# 272      -0.0      0.062     98.976     -1.024
# 271      -0.0      0.062     98.665     -1.335
